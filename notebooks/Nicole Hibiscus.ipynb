# %% [markdown]
# # Nicole hibiscus
#
# Some of these radar images are quite stunning

# %%
from pathlib import Path
from karmapi import base, show

from IPython import display

# %%
tankrain = Path('~/karmapi/tankrain/2016/10/13').expanduser()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/karmapi
# Out:
# /home/jng/karmapi

# %% [markdown]
# # St Davids Hibiscus

# %%
show.show(tankrain / 'wide_0448.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=765x508 at 0x7FB839A4D358>

# %% [markdown]
# # Closer...

# %%
show.show(tankrain / 'local_0448.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=765x508 at 0x7FB839A4D128>

# %%
show.show(tankrain / 'parish_0448.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x515 at 0x7FB839A4D400>
